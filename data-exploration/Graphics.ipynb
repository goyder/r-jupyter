# %% [markdown]
# # Graphics
# A collection of examples of useful plotting techniques in R.

# %%
library(datasets)

# %%
summary(airquality)
# Out:
#      Ozone           Solar.R           Wind             Temp
#  Min.   :  1.00   Min.   :  7.0   Min.   : 1.700   Min.   :56.00
#  1st Qu.: 18.00   1st Qu.:115.8   1st Qu.: 7.400   1st Qu.:72.00
#  Median : 31.50   Median :205.0   Median : 9.700   Median :79.00
#  Mean   : 42.13   Mean   :185.9   Mean   : 9.958   Mean   :77.88
#  3rd Qu.: 63.25   3rd Qu.:258.8   3rd Qu.:11.500   3rd Qu.:85.00
#  Max.   :168.00   Max.   :334.0   Max.   :20.700   Max.   :97.00
#  NA's   :37       NA's   :7
#      Month            Day
#  Min.   :5.000   Min.   : 1.0
#  1st Qu.:6.000   1st Qu.: 8.0
#  Median :7.000   Median :16.0
#  Mean   :6.993   Mean   :15.8
#  3rd Qu.:8.000   3rd Qu.:23.0
#  Max.   :9.000   Max.   :31.0

# %%
boxplot(airquality$Ozone, col="blue")
abline(h=100)
# Out:
# plot without title

# %%
# Getting a bit more clever
airquality <- transform(airquality, Month = factor(Month))
boxplot(Ozone ~ Month, airquality, xlab = "Month", ylab = "Ozone (ppb)")
# Out:
# plot without title

# %%
library(RColorBrewer)
cols <- brewer.pal(10, "BuGn")
# Out:
# Warning message in brewer.pal(10, "BuGn"):
# “n too large, allowed maximum for palette BuGn is 9
# Returning the palette you asked for with that many colors
# ”

# %%
hist(airquality$Ozone, col=cols, breaks=30)
rug(airquality$Ozone)
# Out:
# Plot with title “Histogram of airquality$Ozone”

# %%
with(airquality, plot(Ozone, Wind, col=Month))
# Out:
# plot without title

# %%
with(airquality, plot(Wind, Ozone, main = "Ozone and Wind in New York City", pch = 20))
model <- lm(Ozone ~ Wind, airquality)
abline(model, lwd = 2)
# Out:
# Plot with title “Ozone and Wind in New York City”

# %%
# Multi-plots!
par(mfrow = c(1, 3), mar = c(4, 4, 2, 1), oma = c(0, 0, 2, 0))
with(airquality, {
    plot(Wind, Ozone, main = "Ozone and Wind")
    plot(Solar.R, Ozone, main = "Ozone and Solar Radiation")
    plot(Temp, Ozone, main = "Ozone and Temperature")
    mtext("Ozone and Weather in New York City", outer = TRUE)
})
# Out:
# Plot with title “Ozone and Temperature”

# %%
barplot(table(airquality$Ozone), main="Ozone, my dude.")
# Out:
# Plot with title “Ozone, my dude.”

# %%
jk
