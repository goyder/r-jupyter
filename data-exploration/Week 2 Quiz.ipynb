# %% [markdown]
# # Week 2 Quiz
# Most of these questions can be checked and validated in a notebook before submitting.
# ___

# %%
library(datasets)

# %% [markdown]
# ** Question 1 **
# Under the lattice graphics system, what do the primary plotting functions like xyplot() and bwplot() return?

# %%
library(lattice)

# %%
colnames(airquality)
# Out:
# [1] "Ozone"   "Solar.R" "Wind"    "Temp"    "Month"   "Day"

# %%
plot  <- xyplot(Wind ~ Temp, airquality)

# %%
class(plot)
# Out:
# [1] "trellis"

# %% [markdown]
# **Question 2** What is produced by the following code?

# %%
library(nlme)
library(lattice)
xyplot(weight ~ Time | Diet, BodyWeight)
# Out:
# plot without title

# %% [markdown]
# **Question 4** The following code does NOT result in a plot appearing on the screen device. Why?

# %%
library(lattice)
library(datasets)
data(airquality)
p <- xyplot(Ozone ~ Wind | factor(Month), data = airquality)

# %% [markdown]
# **Question 5** In the lattice system, which of the following functions can be used to finely control the appearance of all lattice plots?
# * splom()
# * trellis.par.set()
# * print.trellis()
# * par()

# %%
?trellis.par.set

# %% [markdown]
# **Question 6** Load the `airquality` dataset. How can we examine the relationship between ozone and wind speed across each month?

# %%
library(ggplot2)

# %%
qplot(Wind, Ozone, data = airquality, facets = . ~ factor(Month))
# Out:
# Warning message:
# “Removed 37 rows containing missing values (geom_point).”
# plot without title

# %%
airquality_transformed <- transform(airquality, Month = factor(Month))
qplot(Wind, Ozone, data = airquality_transformed, facets = . ~ Month)
# Out:
# Warning message:
# “Removed 37 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# **Question 9** When I run the following code I get an error:

# %%
install.packages("ggplot2movies")

# %%
library(ggplot2)
library(ggplot2movies)
g <- ggplot(movies, aes(votes, rating))
print(g)
# Out:
# plot without title
