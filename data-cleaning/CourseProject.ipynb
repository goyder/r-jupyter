# %% [markdown]
# # Getting and Cleaning Data Course Project
# ___
#
# The purpose of this project is to demonstrate your ability to collect, work with, and clean a data set.
#
# ## Review criteria
# 1. The submitted data set is tidy.
# 2. The Github repo contains the required scripts.
# 3. GitHub contains a code book that modifies and updates the available codebooks with the data to indicate all the variables and summaries calculated, along with units, and any other relevant information.
# 4. The README that explains the analysis files is clear and understandable.
# 5. The work submitted for this project is the work of the student who submitted it.
#
# ## Getting and Cleaning Data Course Project
# The purpose of this project is to demonstrate your ability to collect, work with, and clean a data set. The goal is to prepare tidy data that can be used for later analysis. You will be graded by your peers on a series of yes/no questions related to the project. You will be required to submit: 1) a tidy data set as described below, 2) a link to a Github repository with your script for performing the analysis, and 3) a code book that describes the variables, the data, and any transformations or work that you performed to clean up the data called CodeBook.md. You should also include a README.md in the repo with your scripts. This repo explains how all of the scripts work and how they are connected.
#
# One of the most exciting areas in all of data science right now is wearable computing - see for example this article . Companies like Fitbit, Nike, and Jawbone Up are racing to develop the most advanced algorithms to attract new users. The data linked to from the course website represent data collected from the accelerometers from the Samsung Galaxy S smartphone. A full description is available at the site where the data was obtained:
#
# http://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones
#
# Here are the data for the project:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fprojectfiles%2FUCI%20HAR%20Dataset.zip
#
# You should create one R script called run_analysis.R that does the following.
#
# 1. Merges the training and the test sets to create one data set.
# 2. Extracts only the measurements on the mean and standard deviation for each measurement.
# 3. Uses descriptive activity names to name the activities in the data set
# 4. Appropriately labels the data set with descriptive variable names.
# 5. From the data set in step 4, creates a second, independent tidy data set with the average of each variable for each activity and each subject.
#
# Good luck!

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
if (!file.exists("data/course_project_files.zip")) {
    download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fprojectfiles%2FUCI%20HAR%20Dataset.zip", 
                 "data/course_project_files.zip")
}

# %%
unzip("data/course_project_files.zip", exdir="data")

# %%
dir("data/UCI HAR Dataset/")
# Out:
# [1] "activity_labels.txt" "features_info.txt"   "features.txt"
# [4] "README.txt"          "test"                "train"

# %% [markdown]
# ## Review the features file
# The `features.txt` file is a list of the features in the test files. Now, the `X_train.txt` file is really, really large - we'd be better off defining which columns we want to extract first of all, and *then* extract only these columns.

# %%
features <- readLines("data/UCI HAR Dataset/features.txt")

# %%
strsplit(features[[1]], " ")[[1]][[2]]
# Out:
# [1] "tBodyAcc-mean()-X"

# %%
features <- sapply(features, function(x) { strsplit(x, " ")[[1]][[2]]})

# %%
meanandstd <- grepl(features, pattern = "(mean\\(\\)|std\\(\\))")

# %%
colnames <- features[meanandstd]

# %%
colnames
# Out:
#             1 tBodyAcc-mean()-X             2 tBodyAcc-mean()-Y
#             "tBodyAcc-mean()-X"             "tBodyAcc-mean()-Y"
#             3 tBodyAcc-mean()-Z              4 tBodyAcc-std()-X
#             "tBodyAcc-mean()-Z"              "tBodyAcc-std()-X"
#              5 tBodyAcc-std()-Y              6 tBodyAcc-std()-Z
#              "tBodyAcc-std()-Y"              "tBodyAcc-std()-Z"
#         41 tGravityAcc-mean()-X         42 tGravityAcc-mean()-Y
#          "tGravityAcc-mean()-X"          "tGravityAcc-mean()-Y"
#         43 tGravityAcc-mean()-Z          44 tGravityAcc-std()-X
#          "tGravityAcc-mean()-Z"           "tGravityAcc-std()-X"
#          45 tGravityAcc-std()-Y          46 tGravityAcc-std()-Z
#           "tGravityAcc-std()-Y"           "tGravityAcc-std()-Z"
#        81 tBodyAccJerk-mean()-X        82 tBodyAccJerk-mean()-Y
#         "tBodyAccJerk-mean()-X"         "tBodyAccJerk-mean()-Y"
#        83 tBodyAccJerk-mean()-Z         84 tBodyAccJerk-std()-X
#         "tBodyAccJerk-mean()-Z"          "tBodyAccJerk-std()-X"
#         85 tBodyAccJerk-std()-Y         86 tBodyAccJerk-std()-Z
#          "tBodyAccJerk-std()-Y"          "tBodyAccJerk-std()-Z"
#          121 tBodyGyro-mean()-X          122 tBodyGyro-mean()-Y
#            "tBodyGyro-mean()-X"            "tBodyGyro-mean()-Y"
#          123 tBodyGyro-mean()-Z           124 tBodyGyro-std()-X
#            "tBodyGyro-mean()-Z"             "tBodyGyro-std()-X"
#           125 tBodyGyro-std()-Y           126 tBodyGyro-std()-Z
#             "tBodyGyro-std()-Y"             "tBodyGyro-std()-Z"
#      161 tBodyGyroJerk-mean()-X      162 tBodyGyroJerk-mean()-Y
#        "tBodyGyroJerk-mean()-X"        "tBodyGyroJerk-mean()-Y"
#      163 tBodyGyroJerk-mean()-Z       164 tBodyGyroJerk-std()-X
#        "tBodyGyroJerk-mean()-Z"         "tBodyGyroJerk-std()-X"
#       165 tBodyGyroJerk-std()-Y       166 tBodyGyroJerk-std()-Z
#         "tBodyGyroJerk-std()-Y"         "tBodyGyroJerk-std()-Z"
#          201 tBodyAccMag-mean()           202 tBodyAccMag-std()
#            "tBodyAccMag-mean()"             "tBodyAccMag-std()"
#       214 tGravityAccMag-mean()        215 tGravityAccMag-std()
#         "tGravityAccMag-mean()"          "tGravityAccMag-std()"
#      227 tBodyAccJerkMag-mean()       228 tBodyAccJerkMag-std()
#        "tBodyAccJerkMag-mean()"         "tBodyAccJerkMag-std()"
#         240 tBodyGyroMag-mean()          241 tBodyGyroMag-std()
#           "tBodyGyroMag-mean()"            "tBodyGyroMag-std()"
#     253 tBodyGyroJerkMag-mean()      254 tBodyGyroJerkMag-std()
#       "tBodyGyroJerkMag-mean()"        "tBodyGyroJerkMag-std()"
#           266 fBodyAcc-mean()-X           267 fBodyAcc-mean()-Y
#             "fBodyAcc-mean()-X"             "fBodyAcc-mean()-Y"
#           268 fBodyAcc-mean()-Z            269 fBodyAcc-std()-X
#             "fBodyAcc-mean()-Z"              "fBodyAcc-std()-X"
#            270 fBodyAcc-std()-Y            271 fBodyAcc-std()-Z
#              "fBodyAcc-std()-Y"              "fBodyAcc-std()-Z"
#       345 fBodyAccJerk-mean()-X       346 fBodyAccJerk-mean()-Y
#         "fBodyAccJerk-mean()-X"         "fBodyAccJerk-mean()-Y"
#       347 fBodyAccJerk-mean()-Z        348 fBodyAccJerk-std()-X
#         "fBodyAccJerk-mean()-Z"          "fBodyAccJerk-std()-X"
#        349 fBodyAccJerk-std()-Y        350 fBodyAccJerk-std()-Z
#          "fBodyAccJerk-std()-Y"          "fBodyAccJerk-std()-Z"
#          424 fBodyGyro-mean()-X          425 fBodyGyro-mean()-Y
#            "fBodyGyro-mean()-X"            "fBodyGyro-mean()-Y"
#          426 fBodyGyro-mean()-Z           427 fBodyGyro-std()-X
#            "fBodyGyro-mean()-Z"             "fBodyGyro-std()-X"
#           428 fBodyGyro-std()-Y           429 fBodyGyro-std()-Z
#             "fBodyGyro-std()-Y"             "fBodyGyro-std()-Z"
#          503 fBodyAccMag-mean()           504 fBodyAccMag-std()
#            "fBodyAccMag-mean()"             "fBodyAccMag-std()"
#  516 fBodyBodyAccJerkMag-mean()   517 fBodyBodyAccJerkMag-std()
#    "fBodyBodyAccJerkMag-mean()"     "fBodyBodyAccJerkMag-std()"
#     529 fBodyBodyGyroMag-mean()      530 fBodyBodyGyroMag-std()
#       "fBodyBodyGyroMag-mean()"        "fBodyBodyGyroMag-std()"
# 542 fBodyBodyGyroJerkMag-mean()  543 fBodyBodyGyroJerkMag-std()
#   "fBodyBodyGyroJerkMag-mean()"    "fBodyBodyGyroJerkMag-std()"

# %%
colwidths <- sapply(X = meanandstd, FUN = function(x) { ifelse(x, 16, -16)})

# %% [markdown]
# ## Reading in data

# %% [markdown]
# ### Assemble Training Data

# %%
x.training <- read.fwf("data/UCI HAR Dataset//train/X_train.txt", widths=colwidths, n = -1, col.names = colnames)

# %%
y.training <- readLines("data/UCI HAR Dataset/train/y_train.txt")

# %%
subject.training <- readLines("data/UCI HAR Dataset/train/subject_train.txt")

# %%
training <- cbind(x.training, y.training, subject.training)

# %%
training <- training %>% rename(activity = y.training, subject = subject.training)
# Out:
# Error: `y.training`, `subject.training` contains unknown variables
# Traceback:
#
# 1. training %>% rename(activity = y.training, subject = subject.training)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(expr, envir, enclos)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. rename(., activity = y.training, subject = subject.training)
# 10. rename.data.frame(., activity = y.training, subject = subject.training)
# 11. rename_vars(names(.data), !(!(!quos(...))))
# 12. bad_args(unknown_vars, "contains unknown variables")
# 13. glubort(fmt_args(args), ..., .envir = .envir)
# 14. .abort(text)

# %% [markdown]
# ### Assemble test data

# %%
x.test <- read.fwf("data/UCI HAR Dataset/test/X_test.txt", widths=colwidths, n = -1, col.names = colnames)

# %%
y.test <- readLines("data/UCI HAR Dataset/test/y_test.txt")

# %%
subject.test <- readLines("data/UCI HAR Dataset/test/subject_test.txt")

# %%
test <- cbind(x.test, y.test, subject.test)

# %%
test <- test %>% rename(activity = y.test, subject = subject.test)

# %% [markdown]
# ### Merge Data

# %%
total.data <- merge(training, test, all = TRUE)

# %%
names(total.data)
# Out:
#  [1] "tBodyAcc.mean...X"           "tBodyAcc.mean...Y"
#  [3] "tBodyAcc.mean...Z"           "tBodyAcc.std...X"
#  [5] "tBodyAcc.std...Y"            "tBodyAcc.std...Z"
#  [7] "tGravityAcc.mean...X"        "tGravityAcc.mean...Y"
#  [9] "tGravityAcc.mean...Z"        "tGravityAcc.std...X"
# [11] "tGravityAcc.std...Y"         "tGravityAcc.std...Z"
# [13] "tBodyAccJerk.mean...X"       "tBodyAccJerk.mean...Y"
# [15] "tBodyAccJerk.mean...Z"       "tBodyAccJerk.std...X"
# [17] "tBodyAccJerk.std...Y"        "tBodyAccJerk.std...Z"
# [19] "tBodyGyro.mean...X"          "tBodyGyro.mean...Y"
# [21] "tBodyGyro.mean...Z"          "tBodyGyro.std...X"
# [23] "tBodyGyro.std...Y"           "tBodyGyro.std...Z"
# [25] "tBodyGyroJerk.mean...X"      "tBodyGyroJerk.mean...Y"
# [27] "tBodyGyroJerk.mean...Z"      "tBodyGyroJerk.std...X"
# [29] "tBodyGyroJerk.std...Y"       "tBodyGyroJerk.std...Z"
# [31] "tBodyAccMag.mean.."          "tBodyAccMag.std.."
# [33] "tGravityAccMag.mean.."       "tGravityAccMag.std.."
# [35] "tBodyAccJerkMag.mean.."      "tBodyAccJerkMag.std.."
# [37] "tBodyGyroMag.mean.."         "tBodyGyroMag.std.."
# [39] "tBodyGyroJerkMag.mean.."     "tBodyGyroJerkMag.std.."
# [41] "fBodyAcc.mean...X"           "fBodyAcc.mean...Y"
# [43] "fBodyAcc.mean...Z"           "fBodyAcc.std...X"
# [45] "fBodyAcc.std...Y"            "fBodyAcc.std...Z"
# [47] "fBodyAccJerk.mean...X"       "fBodyAccJerk.mean...Y"
# [49] "fBodyAccJerk.mean...Z"       "fBodyAccJerk.std...X"
# [51] "fBodyAccJerk.std...Y"        "fBodyAccJerk.std...Z"
# [53] "fBodyGyro.mean...X"          "fBodyGyro.mean...Y"
# [55] "fBodyGyro.mean...Z"          "fBodyGyro.std...X"
# [57] "fBodyGyro.std...Y"           "fBodyGyro.std...Z"
# [59] "fBodyAccMag.mean.."          "fBodyAccMag.std.."
# [61] "fBodyBodyAccJerkMag.mean.."  "fBodyBodyAccJerkMag.std.."
# [63] "fBodyBodyGyroMag.mean.."     "fBodyBodyGyroMag.std.."
# [65] "fBodyBodyGyroJerkMag.mean.." "fBodyBodyGyroJerkMag.std.."
# [67] "activity"                    "subject"

# %%
col.names <- names(total.data)

# %% [markdown]
# ## Rename variables

# %% [markdown]
# Desired format is:
# * Replace `f`/`t` with `frequency` / `time`
# * Periods to mark between words
# * Remove `bodybody`
# * `mean` and `std` at end of line

# %%
new.col.names <- sub("BodyBody", "Body", col.names)

# %%
new.col.names
# Out:
#  [1] "tBodyAcc.mean...X"       "tBodyAcc.mean...Y"
#  [3] "tBodyAcc.mean...Z"       "tBodyAcc.std...X"
#  [5] "tBodyAcc.std...Y"        "tBodyAcc.std...Z"
#  [7] "tGravityAcc.mean...X"    "tGravityAcc.mean...Y"
#  [9] "tGravityAcc.mean...Z"    "tGravityAcc.std...X"
# [11] "tGravityAcc.std...Y"     "tGravityAcc.std...Z"
# [13] "tBodyAccJerk.mean...X"   "tBodyAccJerk.mean...Y"
# [15] "tBodyAccJerk.mean...Z"   "tBodyAccJerk.std...X"
# [17] "tBodyAccJerk.std...Y"    "tBodyAccJerk.std...Z"
# [19] "tBodyGyro.mean...X"      "tBodyGyro.mean...Y"
# [21] "tBodyGyro.mean...Z"      "tBodyGyro.std...X"
# [23] "tBodyGyro.std...Y"       "tBodyGyro.std...Z"
# [25] "tBodyGyroJerk.mean...X"  "tBodyGyroJerk.mean...Y"
# [27] "tBodyGyroJerk.mean...Z"  "tBodyGyroJerk.std...X"
# [29] "tBodyGyroJerk.std...Y"   "tBodyGyroJerk.std...Z"
# [31] "tBodyAccMag.mean.."      "tBodyAccMag.std.."
# [33] "tGravityAccMag.mean.."   "tGravityAccMag.std.."
# [35] "tBodyAccJerkMag.mean.."  "tBodyAccJerkMag.std.."
# [37] "tBodyGyroMag.mean.."     "tBodyGyroMag.std.."
# [39] "tBodyGyroJerkMag.mean.." "tBodyGyroJerkMag.std.."
# [41] "fBodyAcc.mean...X"       "fBodyAcc.mean...Y"
# [43] "fBodyAcc.mean...Z"       "fBodyAcc.std...X"
# [45] "fBodyAcc.std...Y"        "fBodyAcc.std...Z"
# [47] "fBodyAccJerk.mean...X"   "fBodyAccJerk.mean...Y"
# [49] "fBodyAccJerk.mean...Z"   "fBodyAccJerk.std...X"
# [51] "fBodyAccJerk.std...Y"    "fBodyAccJerk.std...Z"
# [53] "fBodyGyro.mean...X"      "fBodyGyro.mean...Y"
# [55] "fBodyGyro.mean...Z"      "fBodyGyro.std...X"
# [57] "fBodyGyro.std...Y"       "fBodyGyro.std...Z"
# [59] "fBodyAccMag.mean.."      "fBodyAccMag.std.."
# [61] "fBodyAccJerkMag.mean.."  "fBodyAccJerkMag.std.."
# [63] "fBodyGyroMag.mean.."     "fBodyGyroMag.std.."
# [65] "fBodyGyroJerkMag.mean.." "fBodyGyroJerkMag.std.."
# [67] "activity"                "subject"

# %%
new.col.names <- gsub("([A-Z])", "\\.\\1", new.col.names)

# %%
head(new.col.names)
# Out:
# [1] "t.Body.Acc.mean....X" "t.Body.Acc.mean....Y" "t.Body.Acc.mean....Z"
# [4] "t.Body.Acc.std....X"  "t.Body.Acc.std....Y"  "t.Body.Acc.std....Z"

# %%
new.col.names <- gsub("(mean)(.*)", "\\2.mean", new.col.names)

# %%
new.col.names <- gsub("(std)(.*)", "\\2.std", new.col.names)

# %%
new.col.names <- gsub("(\\.+)", "\\.", new.col.names)

# %%
new.col.names <- gsub("(^t)", "time", new.col.names)

# %%
new.col.names <- gsub("(^f)", "frequency", new.col.names)

# %%
new.col.names <- gsub("(Acc)", "acceleration", new.col.names)

# %%
head(new.col.names)
# Out:
# [1] "time.Body.acceleration.X.mean" "time.Body.acceleration.Y.mean"
# [3] "time.Body.acceleration.Z.mean" "time.Body.acceleration.X.std"
# [5] "time.Body.acceleration.Y.std"  "time.Body.acceleration.Z.std"

# %%
tolower(new.col.names)
# Out:
#  [1] "time.body.acceleration.x.mean"
#  [2] "time.body.acceleration.y.mean"
#  [3] "time.body.acceleration.z.mean"
#  [4] "time.body.acceleration.x.std"
#  [5] "time.body.acceleration.y.std"
#  [6] "time.body.acceleration.z.std"
#  [7] "time.gravity.acceleration.x.mean"
#  [8] "time.gravity.acceleration.y.mean"
#  [9] "time.gravity.acceleration.z.mean"
# [10] "time.gravity.acceleration.x.std"
# [11] "time.gravity.acceleration.y.std"
# [12] "time.gravity.acceleration.z.std"
# [13] "time.body.acceleration.jerk.x.mean"
# [14] "time.body.acceleration.jerk.y.mean"
# [15] "time.body.acceleration.jerk.z.mean"
# [16] "time.body.acceleration.jerk.x.std"
# [17] "time.body.acceleration.jerk.y.std"
# [18] "time.body.acceleration.jerk.z.std"
# [19] "time.body.gyro.x.mean"
# [20] "time.body.gyro.y.mean"
# [21] "time.body.gyro.z.mean"
# [22] "time.body.gyro.x.std"
# [23] "time.body.gyro.y.std"
# [24] "time.body.gyro.z.std"
# [25] "time.body.gyro.jerk.x.mean"
# [26] "time.body.gyro.jerk.y.mean"
# [27] "time.body.gyro.jerk.z.mean"
# [28] "time.body.gyro.jerk.x.std"
# [29] "time.body.gyro.jerk.y.std"
# [30] "time.body.gyro.jerk.z.std"
# [31] "time.body.acceleration.mag.mean"
# [32] "time.body.acceleration.mag.std"
# [33] "time.gravity.acceleration.mag.mean"
# [34] "time.gravity.acceleration.mag.std"
# [35] "time.body.acceleration.jerk.mag.mean"
# [36] "time.body.acceleration.jerk.mag.std"
# [37] "time.body.gyro.mag.mean"
# [38] "time.body.gyro.mag.std"
# [39] "time.body.gyro.jerk.mag.mean"
# [40] "time.body.gyro.jerk.mag.std"
# [41] "frequency.body.acceleration.x.mean"
# [42] "frequency.body.acceleration.y.mean"
# [43] "frequency.body.acceleration.z.mean"
# [44] "frequency.body.acceleration.x.std"
# [45] "frequency.body.acceleration.y.std"
# [46] "frequency.body.acceleration.z.std"
# [47] "frequency.body.acceleration.jerk.x.mean"
# [48] "frequency.body.acceleration.jerk.y.mean"
# [49] "frequency.body.acceleration.jerk.z.mean"
# [50] "frequency.body.acceleration.jerk.x.std"
# [51] "frequency.body.acceleration.jerk.y.std"
# [52] "frequency.body.acceleration.jerk.z.std"
# [53] "frequency.body.gyro.x.mean"
# [54] "frequency.body.gyro.y.mean"
# [55] "frequency.body.gyro.z.mean"
# [56] "frequency.body.gyro.x.std"
# [57] "frequency.body.gyro.y.std"
# [58] "frequency.body.gyro.z.std"
# [59] "frequency.body.acceleration.mag.mean"
# [60] "frequency.body.acceleration.mag.std"
# [61] "frequency.body.acceleration.jerk.mag.mean"
# [62] "frequency.body.acceleration.jerk.mag.std"
# [63] "frequency.body.gyro.mag.mean"
# [64] "frequency.body.gyro.mag.std"
# [65] "frequency.body.gyro.jerk.mag.mean"
# [66] "frequency.body.gyro.jerk.mag.std"
# [67] "activity"
# [68] "subject"

# %%
names(total.data) <- new.col.names

# %% [markdown]
# ## Replace activity numbers with activity names

# %%
total.data$activity <- revalue(x = total.data$activity, 
                             c("1" = "walking", "2" = "walkingupstairs", "3" = "walkingdownstairs", 
                               "4" = "sitting", "5" = "standing", "6" = "laying"))

# %%
head(total.data)
# Out:
#   time.Body.acceleration.X.mean time.Body.acceleration.Y.mean
# 1 -1.0000000                     0.1775221600
# 2 -0.8723954                     0.1546078000
# 3 -0.8538482                     0.2053651600
# 4 -0.5920043                     0.1469832700
# 5 -0.5210621                    -0.0001832748
# 6 -0.5038227                    -0.5942073800
#   time.Body.acceleration.Z.mean time.Body.acceleration.X.std
# 1  0.54393929                   -0.10078555
# 2  0.33075342                   -0.06063940
# 3 -0.11634455                   -0.05714196
# 4  0.05256077                   -0.42436336
# 5  0.10661589                   -0.34411877
# 6  0.26480435                   -0.70340175
#   time.Body.acceleration.Y.std time.Body.acceleration.Z.std
# 1 -0.12621085                   0.35953802
# 2 -0.30688449                   0.06857798
# 3 -0.07570973                  -0.30853842
# 4 -0.22019354                  -0.70417659
# 5 -0.49510932                  -0.46239833
# 6  0.67248690                  -0.46498511
#   time.Gravity.acceleration.X.mean time.Gravity.acceleration.Y.mean
# 1  0.26331618                      0.3709743
# 2  0.15796616                      0.3996528
# 3 -0.20846369                      0.7500424
# 4  0.09429582                      0.7600206
# 5 -0.07149524                      0.5476480
# 6 -0.60124091                      0.7360639
#   time.Gravity.acceleration.Z.mean time.Gravity.acceleration.X.std ⋯
# 1 0.6252615                         0.7830280                      ⋯
# 2 0.6992262                         0.6999877                      ⋯
# 3 0.4937287                         1.0000000                      ⋯
# 4 0.4341949                         0.3319481                      ⋯
# 5 0.7526245                         0.4638767                      ⋯
# 6 0.6609761                        -0.4146724                      ⋯
#   frequency.Body.acceleration.Mag.mean frequency.Body.acceleration.Mag.std
# 1  0.25436641                          1.0000000
# 2  0.08208614                          0.8597170
# 3  0.22740813                          0.5027986
# 4 -0.10971764                          0.1462056
# 5 -0.07171502                          0.1243441
# 6 -0.20493853                          0.6020663
#   frequency.Body.acceleration.Jerk.Mag.mean
# 1 -0.8480197
# 2 -0.7651400
# 3 -0.6589593
# 4 -0.7460609
# 5 -0.8287394
# 6 -0.9072344
#   frequency.Body.acceleration.Jerk.Mag.std frequency.Body.Gyro.Mag.mean
# 1 -0.7811734                               -0.7187075
# 2 -0.6977112                               -0.6650375
# 3 -0.6846475                               -0.6977197
# 4 -0.7711571                               -0.7518159
# 5 -0.8286772                               -0.8310883
# 6 -0.8940982                               -0.7859358
#   frequency.Body.Gyro.Mag.std frequency.Body.Gyro.Jerk.Mag.mean
# 1 -0.7191602                  -0.8092249
# 2 -0.5784044                  -0.8033907
# 3 -0.7486869                  -0.7606992
# 4 -0.8552519                  -0.7221136
# 5 -0.8378409                  -0.8356959
# 6 -0.4291497                  -0.9441093
#   frequency.Body.Gyro.Jerk.Mag.std activity subject
# 1 -0.7377875                       laying   14
# 2 -0.7047181                       laying   14
# 3 -0.7924713                       laying   6
# 4 -0.7678528                       laying   20
# 5 -0.8195921                       laying   12
# 6 -0.9527274                       laying   25

# %% [markdown]
# ## Generate data set with the average of each variable for each activity and each subject

# %%
library(reshape2)

# %%
melted.data <- melt(total.data, id=c("subject", "activity"))

# %%
dcast(melted.data, activity ~ variable, mean)
# Out:
#   activity          time.Body.acceleration.X.mean time.Body.acceleration.Y.mean
# 1 walking           0.2763369                     -0.01790683
# 2 walkingupstairs   0.2622946                     -0.02592329
# 3 walkingdownstairs 0.2881372                     -0.01631193
# 4 sitting           0.2730596                     -0.01268957
# 5 standing          0.2791535                     -0.01615189
# 6 laying            0.2686486                     -0.01831773
#   time.Body.acceleration.Z.mean time.Body.acceleration.X.std
# 1 -0.1088817                    -0.3146445
# 2 -0.1205379                    -0.2379897
# 3 -0.1057616                     0.1007663
# 4 -0.1055170                    -0.9834462
# 5 -0.1065869                    -0.9844347
# 6 -0.1074356                    -0.9609324
#   time.Body.acceleration.Y.std time.Body.acceleration.Z.std
# 1 -0.02358295                  -0.2739208
# 2 -0.01603251                  -0.1754497
# 3  0.05954862                  -0.1908045
# 4 -0.93488056                  -0.9389816
# 5 -0.93250871                  -0.9399135
# 6 -0.94350719                  -0.9480693
#   time.Gravity.acceleration.X.mean time.Gravity.acceleration.Y.mean
# 1  0.9349916                       -0.1967135
# 2  0.8750034                       -0.2813772
# 3  0.9264574                       -0.1685072
# 4  0.8797312                        0.1087135
# 5  0.9414796                       -0.1842465
# 6 -0.3750213                        0.6222704
#   time.Gravity.acceleration.Z.mean ⋯ frequency.Body.Gyro.Y.std
# 1 -0.05382512                      ⋯ -0.3319615
# 2 -0.14079567                      ⋯ -0.2931818
# 3 -0.04797090                      ⋯ -0.3618537
# 4  0.15377409                      ⋯ -0.9640337
# 5 -0.01405196                      ⋯ -0.9594986
# 6  0.55561247                      ⋯ -0.9613654
#   frequency.Body.Gyro.Z.std frequency.Body.acceleration.Mag.mean
# 1 -0.4105691                -0.2755581
# 2 -0.2920413                -0.2620281
# 3 -0.3804100                 0.1428494
# 4 -0.9610302                -0.9524104
# 5 -0.9606892                -0.9558681
# 6 -0.9667252                -0.9476727
#   frequency.Body.acceleration.Mag.std frequency.Body.acceleration.Jerk.Mag.mean
# 1 -0.48000228                         -0.214653972
# 2 -0.36175346                         -0.353962000
# 3 -0.07542517                          0.004762459
# 4 -0.94200015                         -0.978684370
# 5 -0.94960161                         -0.971090424
# 6 -0.93491667                         -0.974300115
#   frequency.Body.acceleration.Jerk.Mag.std frequency.Body.Gyro.Mag.mean
# 1 -0.22161777                              -0.4091730
# 2 -0.43420673                              -0.4497814
# 3 -0.04227142                              -0.2895258
# 4 -0.97815477                              -0.9642961
# 5 -0.97094797                              -0.9479085
# 6 -0.97318340                              -0.9548545
#   frequency.Body.Gyro.Mag.std frequency.Body.Gyro.Jerk.Mag.mean
# 1 -0.4738331                  -0.5155168
# 2 -0.3814064                  -0.6586945
# 3 -0.3612310                  -0.4380073
# 4 -0.9516417                  -0.9853356
# 5 -0.9306367                  -0.9748860
# 6 -0.9421157                  -0.9779682
#   frequency.Body.Gyro.Jerk.Mag.std
# 1 -0.5144048
# 2 -0.7030835
# 3 -0.4864430
# 4 -0.9844914
# 5 -0.9734611
# 6 -0.9766482

# %%
cast(melted.data, subject ~ variable, mean)
# Out:
#    subject time.Body.acceleration.X.mean time.Body.acceleration.Y.mean
# 1  1       0.2656969                     -0.01829817
# 2  11      0.2765853                     -0.01912725
# 3  14      0.2701846                     -0.01625482
# 4  15      0.2782134                     -0.01646448
# 5  16      0.2778874                     -0.01585679
# 6  17      0.2740295                     -0.01754160
# 7  19      0.2697235                     -0.01820315
# 8  21      0.2774665                     -0.01766646
# 9  22      0.2747677                     -0.01682736
# 10 23      0.2734933                     -0.01958926
# 11 25      0.2753015                     -0.01932218
# 12 26      0.2730366                     -0.01616873
# 13 27      0.2772646                     -0.01679692
# 14 28      0.2775326                     -0.01917214
# 15 29      0.2791115                     -0.01847195
# 16 3       0.2734287                     -0.01785607
# 17 30      0.2763058                     -0.01758561
# 18 5       0.2791780                     -0.01548335
# 19 6       0.2723766                     -0.01756970
# 20 7       0.2702117                     -0.01879049
# 21 8       0.2707591                     -0.01818950
# 22 10      0.2768485                     -0.01783579
# 23 12      0.2736087                     -0.01833720
# 24 13      0.2758959                     -0.01765048
# 25 18      0.2763242                     -0.01728315
# 26 2       0.2731131                     -0.01913232
# 27 20      0.2684258                     -0.01759130
# 28 24      0.2767670                     -0.01768225
# 29 4       0.2741831                     -0.01480815
# 30 9       0.2703138                     -0.02094666
#    time.Body.acceleration.Z.mean time.Body.acceleration.X.std
# 1  -0.1078457                    -0.5457953
# 2  -0.1089418                    -0.5894765
# 3  -0.1009859                    -0.6116711
# 4  -0.1125636                    -0.5565412
# 5  -0.1072639                    -0.6681615
# 6  -0.1091999                    -0.6084552
# 7  -0.1182772                    -0.5746589
# 8  -0.1087785                    -0.6723239
# 9  -0.1086704                    -0.5460900
# 10 -0.1090940                    -0.6225940
# 11 -0.1096290                    -0.7162645
# 12 -0.1076379                    -0.6231010
# 13 -0.1108483                    -0.6609761
# 14 -0.1097109                    -0.6490404
# 15 -0.1086756                    -0.5742954
# 16 -0.1064926                    -0.6234136
# 17 -0.1058936                    -0.6158908
# 18 -0.1056617                    -0.5076910
# 19 -0.1159945                    -0.5050861
# 20 -0.1124924                    -0.5775183
# 21 -0.1068096                    -0.5829589
# 22 -0.1113015                    -0.5378077
# 23 -0.1066491                    -0.5839622
# 24 -0.1091353                    -0.6248445
# 25 -0.1081123                    -0.6946169
# 26 -0.1156500                    -0.6055865
# 27 -0.1080291                    -0.6048467
# 28 -0.1079145                    -0.6754592
# 29 -0.1075214                    -0.6052117
# 30 -0.1012338                    -0.5556565
#    time.Body.acceleration.Y.std time.Body.acceleration.Z.std
# 1  -0.3677162                   -0.5026457
# 2  -0.4903793                   -0.6653243
# 3  -0.3747308                   -0.2935427
# 4  -0.4816795                   -0.7057066
# 5  -0.6499471                   -0.6038199
# 6  -0.5670053                   -0.6605828
# 7  -0.5070351                   -0.6491847
# 8  -0.5655852                   -0.6696218
# 9  -0.4911884                   -0.6550897
# 10 -0.5320785                   -0.4505572
# 11 -0.5314210                   -0.6470956
# 12 -0.5859671                   -0.7049806
# 13 -0.6304605                   -0.6832153
# 14 -0.5736519                   -0.6858214
# 15 -0.5984003                   -0.6064613
# 16 -0.4800159                   -0.6536256
# 17 -0.5190474                   -0.5226433
# 18 -0.4027249                   -0.6464436
# 19 -0.3684037                   -0.6725120
# 20 -0.5464034                   -0.4564736
# 21 -0.3493837                   -0.4994727
# 22 -0.4974059                   -0.6147770
# 23 -0.5220400                   -0.6992935
# 24 -0.4488161                   -0.5872306
# 25 -0.6271175                   -0.7015960
# 26 -0.4289630                   -0.5893601
# 27 -0.3693367                   -0.6347873
# 28 -0.5824907                   -0.6364975
# 29 -0.5099294                   -0.7094927
# 30 -0.5758879                   -0.5061118
#    time.Gravity.acceleration.X.mean time.Gravity.acceleration.Y.mean
# 1  0.7448674                        -0.08255626
# 2  0.7305262                         0.05273870
# 3  0.6720812                        -0.11170139
# 4  0.6888725                         0.10266049
# 5  0.7009061                        -0.06052360
# 6  0.6989374                        -0.01373470
# 7  0.4753230                         0.09640526
# 8  0.6457760                        -0.07509631
# 9  0.6093909                         0.03150987
# 10 0.6623247                         0.01462092
# 11 0.6723866                         0.04716014
# 12 0.6151235                         0.10870478
# 13 0.6272301                         0.03224239
# 14 0.6237679                        -0.14757776
# 15 0.6830676                         0.11548976
# 16 0.7078144                        -0.02605905
# 17 0.6968582                         0.05126982
# 18 0.6981537                         0.11231311
# 19 0.6887021                         0.01620555
# 20 0.6812891                        -0.04202215
# 21 0.6474982                         0.03032111
# 22 0.6429057                        -0.07402485
# 23 0.6992225                         0.02997678
# 24 0.7099965                        -0.04208581
# 25 0.7168632                        -0.01578200
# 26 0.6607829                        -0.14721989
# 27 0.6280406                        -0.03730595
# 28 0.6949813                         0.07295097
# 29 0.7065930                         0.11259120
# 30 0.6708455                        -0.04674470
#    time.Gravity.acceleration.Z.mean ⋯ frequency.Body.Gyro.Y.std
# 1   0.07233987                      ⋯ -0.4298258
# 2   0.14020986                      ⋯ -0.6708927
# 3  -0.16117973                      ⋯ -0.3488642
# 4   0.03728977                      ⋯ -0.6845047
# 5   0.04020755                      ⋯ -0.8094214
# 6  -0.01770424                      ⋯ -0.7613352
# 7   0.23301140                      ⋯ -0.6501054
# 8   0.03218518                      ⋯ -0.7713883
# 9   0.23588786                      ⋯ -0.7820461
# 10  0.05186625                      ⋯ -0.5078505
# 11  0.23922604                      ⋯ -0.7235844
# 12  0.23410701                      ⋯ -0.8036353
# 13  0.14116870                      ⋯ -0.8087918
# 14 -0.04699310                      ⋯ -0.7408195
# 15  0.20821537                      ⋯ -0.5888580
# 16  0.04809379                      ⋯ -0.7585053
# 17  0.18434318                      ⋯ -0.4963104
# 18  0.09216072                      ⋯ -0.7022904
# 19  0.04752000                      ⋯ -0.6332362
# 20  0.03421607                      ⋯ -0.6711619
# 21  0.08365424                      ⋯ -0.5730873
# 22  0.05520472                      ⋯ -0.5659437
# 23  0.03302955                      ⋯ -0.7334567
# 24  0.04430105                      ⋯ -0.6506236
# 25  0.08999017                      ⋯ -0.7596656
# 26  0.13486534                      ⋯ -0.7271677
# 27  0.10723076                      ⋯ -0.5675886
# 28  0.06232277                      ⋯ -0.7719698
# 29  0.16413090                      ⋯ -0.7828857
# 30  0.10435365                      ⋯ -0.6672032
#    frequency.Body.Gyro.Z.std frequency.Body.acceleration.Mag.mean
# 1  -0.6504762                -0.4784485
# 2  -0.7559606                -0.6115281
# 3  -0.4076721                -0.4908742
# 4  -0.7516965                -0.5629484
# 5  -0.7569936                -0.6669625
# 6  -0.7451015                -0.6461892
# 7  -0.6947291                -0.5564044
# 8  -0.7283193                -0.6586647
# 9  -0.6906794                -0.5743332
# 10 -0.6441310                -0.5290293
# 11 -0.7712089                -0.6950197
# 12 -0.7359424                -0.6317570
# 13 -0.6971473                -0.6671858
# 14 -0.7002913                -0.6287632
# 15 -0.7491632                -0.5892940
# 16 -0.7510089                -0.5790765
# 17 -0.6202534                -0.6003721
# 18 -0.6693537                -0.5285030
# 19 -0.6730203                -0.4739749
# 20 -0.6989495                -0.5183239
# 21 -0.5539686                -0.5121068
# 22 -0.6459477                -0.5187340
# 23 -0.7082332                -0.5592837
# 24 -0.6857745                -0.5899281
# 25 -0.7663817                -0.6977329
# 26 -0.6831145                -0.5145699
# 27 -0.5750022                -0.5602789
# 28 -0.7357499                -0.6501219
# 29 -0.7670896                -0.6020980
# 30 -0.6194686                -0.5531864
#    frequency.Body.acceleration.Mag.std
# 1  -0.5897102
# 2  -0.6744702
# 3  -0.5482699
# 4  -0.6236556
# 5  -0.7126810
# 6  -0.6875369
# 7  -0.6898609
# 8  -0.7143457
# 9  -0.6738962
# 10 -0.6570489
# 11 -0.6953679
# 12 -0.6739178
# 13 -0.7348831
# 14 -0.6969940
# 15 -0.6393142
# 16 -0.6630798
# 17 -0.6465228
# 18 -0.5942595
# 19 -0.5709103
# 20 -0.5838198
# 21 -0.6516381
# 22 -0.6331961
# 23 -0.6505333
# 24 -0.6653449
# 25 -0.7339041
# 26 -0.6466623
# 27 -0.6483062
# 28 -0.7059284
# 29 -0.6729483
# 30 -0.6244568
#    frequency.Body.acceleration.Jerk.Mag.mean
# 1  -0.4990758
# 2  -0.6561335
# 3  -0.5968963
# 4  -0.6148176
# 5  -0.7131676
# 6  -0.6975756
# 7  -0.5760646
# 8  -0.6797426
# 9  -0.5854425
# 10 -0.5426633
# 11 -0.7791901
# 12 -0.6792783
# 13 -0.6885728
# 14 -0.6754287
# 15 -0.6098799
# 16 -0.6047521
# 17 -0.6563397
# 18 -0.5731762
# 19 -0.4948823
# 20 -0.5533600
# 21 -0.5292449
# 22 -0.5151408
# 23 -0.5642392
# 24 -0.6072953
# 25 -0.7423238
# 26 -0.5097464
# 27 -0.5845714
# 28 -0.6968456
# 29 -0.6350190
# 30 -0.6091937
#    frequency.Body.acceleration.Jerk.Mag.std frequency.Body.Gyro.Mag.mean
# 1  -0.5418231                               -0.5350028
# 2  -0.6769251                               -0.7575859
# 3  -0.6192151                               -0.5430305
# 4  -0.6431012                               -0.7323945
# 5  -0.7298694                               -0.8171288
# 6  -0.6925958                               -0.7694986
# 7  -0.6410890                               -0.6362880
# 8  -0.6837251                               -0.7764731
# 9  -0.5992869                               -0.7281668
# 10 -0.5838323                               -0.5346572
# 11 -0.7835472                               -0.7542361
# 12 -0.6780258                               -0.7705049
# 13 -0.7075314                               -0.7859536
# 14 -0.7064158                               -0.7379081
# 15 -0.6364345                               -0.7220184
# 16 -0.6156437                               -0.7168221
# 17 -0.6646003                               -0.6696005
# 18 -0.6134851                               -0.6773558
# 19 -0.5167113                               -0.5791301
# 20 -0.5506833                               -0.6288773
# 21 -0.6180274                               -0.6099843
# 22 -0.5530274                               -0.6614966
# 23 -0.5716149                               -0.7173117
# 24 -0.6170755                               -0.6522253
# 25 -0.7501900                               -0.8162866
# 26 -0.5188008                               -0.6997429
# 27 -0.5973510                               -0.6069709
# 28 -0.6824471                               -0.7541316
# 29 -0.6665067                               -0.7456508
# 30 -0.6116193                               -0.7008631
#    frequency.Body.Gyro.Mag.std frequency.Body.Gyro.Jerk.Mag.mean
# 1  -0.5665767                  -0.6459707
# 2  -0.7112672                  -0.8648270
# 3  -0.5169305                  -0.7175901
# 4  -0.6953468                  -0.8368019
# 5  -0.8020782                  -0.8727723
# 6  -0.7822325                  -0.8291245
# 7  -0.6623260                  -0.7195190
# 8  -0.7931585                  -0.8262750
# 9  -0.6996001                  -0.8301920
# 10 -0.6322885                  -0.5841110
# 11 -0.6972131                  -0.8759707
# 12 -0.7826243                  -0.8238653
# 13 -0.7778104                  -0.8375860
# 14 -0.7437846                  -0.8068822
# 15 -0.6714543                  -0.8404642
# 16 -0.7038394                  -0.8100855
# 17 -0.5891927                  -0.8112923
# 18 -0.7157311                  -0.7488293
# 19 -0.6573687                  -0.6518869
# 20 -0.6509236                  -0.6688792
# 21 -0.6366739                  -0.7021562
# 22 -0.6660146                  -0.7677801
# 23 -0.7194381                  -0.7899029
# 24 -0.6919152                  -0.7120544
# 25 -0.7897777                  -0.8846630
# 26 -0.7253103                  -0.7516151
# 27 -0.6358163                  -0.6926381
# 28 -0.7820763                  -0.7950192
# 29 -0.7325863                  -0.8388332
# 30 -0.6977294                  -0.7864740
#    frequency.Body.Gyro.Jerk.Mag.std
# 1  -0.6858113
# 2  -0.8792540
# 3  -0.7605601
# 4  -0.8496345
# 5  -0.8865332
# 6  -0.8337010
# 7  -0.7542237
# 8  -0.8349499
# 9  -0.8355972
# 10 -0.5937353
# 11 -0.8777150
# 12 -0.8239914
# 13 -0.8482600
# 14 -0.8184485
# 15 -0.8514624
# 16 -0.8100327
# 17 -0.8228056
# 18 -0.7356106
# 19 -0.6601759
# 20 -0.6689634
# 21 -0.7557173
# 22 -0.7871443
# 23 -0.7973615
# 24 -0.7331836
# 25 -0.9022068
# 26 -0.7441950
# 27 -0.6946800
# 28 -0.7961573
# 29 -0.8630969
# 30 -0.8012963

# %%
`

# %%
dcast(melted.data, activity + subject~ variable, mean)
# Out:
#     activity subject time.Body.acceleration.X.mean
# 1   walking  1       0.2773308
# 2   walking  11      0.2718219
# 3   walking  14      0.2719596
# 4   walking  15      0.2738992
# 5   walking  16      0.2760236
# 6   walking  17      0.2723419
# 7   walking  19      0.2739312
# 8   walking  21      0.2791835
# 9   walking  22      0.2788646
# 10  walking  23      0.2732119
# 11  walking  25      0.2789928
# 12  walking  26      0.2792644
# 13  walking  27      0.2768495
# 14  walking  28      0.2812282
# 15  walking  29      0.2719999
# 16  walking  3       0.2755675
# 17  walking  30      0.2764068
# 18  walking  5       0.2778423
# 19  walking  6       0.2836589
# 20  walking  7       0.2755930
# 21  walking  8       0.2746863
# 22  walking  10      0.2785741
# 23  walking  12      0.2771287
# 24  walking  13      0.2758831
# 25  walking  18      0.2738878
# 26  walking  2       0.2764266
# 27  walking  20      0.2725893
# 28  walking  24      0.2769808
# 29  walking  4       0.2785820
# 30  walking  9       0.2785028
# ⋮   ⋮        ⋮       ⋮
# 151 laying   1       0.2215982
# 152 laying   11      0.2805930
# 153 laying   14      0.2332754
# 154 laying   15      0.2894757
# 155 laying   16      0.2742272
# 156 laying   17      0.2697801
# 157 laying   19      0.2726537
# 158 laying   21      0.2713255
# 159 laying   22      0.2799597
# 160 laying   23      0.2740380
# 161 laying   25      0.2507918
# 162 laying   26      0.2716459
# 163 laying   27      0.2741025
# 164 laying   28      0.2759135
# 165 laying   29      0.2872952
# 166 laying   3       0.2755169
# 167 laying   30      0.2810339
# 168 laying   5       0.2783343
# 169 laying   6       0.2486565
# 170 laying   7       0.2501767
# 171 laying   8       0.2612543
# 172 laying   10      0.2802306
# 173 laying   12      0.2601134
# 174 laying   13      0.2767164
# 175 laying   18      0.2746916
# 176 laying   2       0.2813734
# 177 laying   20      0.2395079
# 178 laying   24      0.2728505
# 179 laying   4       0.2635592
# 180 laying   9       0.2591955
#     time.Body.acceleration.Y.mean time.Body.acceleration.Z.mean
# 1   -0.01738382                   -0.11114810
# 2   -0.01664758                   -0.10609630
# 3   -0.02177854                   -0.10675637
# 4   -0.01708097                   -0.10762182
# 5   -0.02042869                   -0.10880405
# 6   -0.01848754                   -0.10979212
# 7   -0.01917736                   -0.12273667
# 8   -0.01816103                   -0.10431933
# 9   -0.01672136                   -0.10711251
# 10  -0.01836187                   -0.11338299
# 11  -0.01864776                   -0.10873764
# 12  -0.01542596                   -0.10892701
# 13  -0.01664788                   -0.11282229
# 14  -0.01567597                   -0.10371471
# 15  -0.01629156                   -0.10663243
# 16  -0.01717678                   -0.11267486
# 17  -0.01758804                   -0.09862471
# 18  -0.01728503                   -0.10774178
# 19  -0.01689542                   -0.11030317
# 20  -0.01865367                   -0.11091223
# 21  -0.01866289                   -0.10725209
# 22  -0.01702235                   -0.10905751
# 23  -0.01556093                   -0.10316111
# 24  -0.01856607                   -0.11143146
# 25  -0.01780236                   -0.10421832
# 26  -0.01859492                   -0.10550036
# 27  -0.02119999                   -0.11353948
# 28  -0.02254464                   -0.11059595
# 29  -0.01483995                   -0.11140306
# 30  -0.01808920                   -0.11082051
# ⋮   ⋮                             ⋮
# 151 -0.04051395                   -0.11320355
# 152 -0.01765981                   -0.10878658
# 153 -0.01134247                   -0.08683333
# 154 -0.01662965                   -0.11853024
# 155 -0.01661035                   -0.10731049
# 156 -0.01684620                   -0.10700628
# 157 -0.01714269                   -0.10898146
# 158 -0.01842330                   -0.10325383
# 159 -0.01426299                   -0.11080092
# 160 -0.02165538                   -0.10425678
# 161 -0.01889437                   -0.10042883
# 162 -0.01918957                   -0.10500254
# 163 -0.01798676                   -0.10769973
# 164 -0.01675379                   -0.10834485
# 165 -0.01719655                   -0.10946207
# 166 -0.01895568                   -0.10130048
# 167 -0.01944941                   -0.10365815
# 168 -0.01830421                   -0.10793760
# 169 -0.01025292                   -0.13311957
# 170 -0.02044115                   -0.10136104
# 171 -0.02122817                   -0.10224537
# 172 -0.02429448                   -0.11716864
# 173 -0.01752039                   -0.10816013
# 174 -0.02044045                   -0.10433186
# 175 -0.01739377                   -0.10769893
# 176 -0.01815874                   -0.10724561
# 177 -0.01444063                   -0.10427432
# 178 -0.01735552                   -0.10723624
# 179 -0.01500318                   -0.11068815
# 180 -0.02052682                   -0.10754972
#     time.Body.acceleration.X.std time.Body.acceleration.Y.std
# 1   -0.283740259                  0.11446134
# 2   -0.422842072                 -0.05221208
# 3   -0.402639098                 -0.05361267
# 4   -0.327961801                  0.13891292
# 5   -0.404692524                 -0.31456976
# 6   -0.319500173                 -0.01757979
# 7   -0.048904941                  0.18180156
# 8   -0.297814844                  0.05408805
# 9   -0.008659219                  0.10038425
# 10  -0.313521773                 -0.11902059
# 11  -0.596007444                 -0.16185241
# 12  -0.340185528                 -0.13635139
# 13  -0.348475561                 -0.18730121
# 14  -0.293003522                 -0.11788619
# 15  -0.174337940                 -0.09175406
# 16  -0.360356726                 -0.06991407
# 17  -0.346394275                 -0.17355002
# 18  -0.294098534                  0.07674840
# 19  -0.296538717                  0.16421388
# 20  -0.327243241                 -0.07726186
# 21  -0.173605736                  0.38078205
# 22  -0.178709734                 -0.02274317
# 23  -0.128898533                 -0.12278329
# 24  -0.346980394                  0.14186669
# 25  -0.376005521                 -0.22700587
# 26  -0.423642838                 -0.07809125
# 27  -0.208342792                  0.48977181
# 28  -0.470762366                 -0.15412750
# 29  -0.440829971                 -0.07882674
# 30  -0.238353563                 -0.20169696
# ⋮   ⋮                            ⋮
# 151 -0.9280565                   -0.8368274
# 152 -0.9847773                   -0.9721969
# 153 -0.9175019                   -0.9096970
# 154 -0.9722556                   -0.9627594
# 155 -0.9736914                   -0.9430612
# 156 -0.9729606                   -0.9447929
# 157 -0.9650196                   -0.9734500
# 158 -0.9550199                   -0.9569594
# 159 -0.9477353                   -0.9132763
# 160 -0.9567564                   -0.9763098
# 161 -0.9091165                   -0.6917707
# 162 -0.9694454                   -0.9832314
# 163 -0.9784552                   -0.9837360
# 164 -0.9688883                   -0.9453868
# 165 -0.9842196                   -0.9902409
# 166 -0.9827766                   -0.9620575
# 167 -0.9763625                   -0.9542018
# 168 -0.9659345                   -0.9692956
# 169 -0.9340494                   -0.9246448
# 170 -0.9365136                   -0.9262627
# 171 -0.9430412                   -0.9348912
# 172 -0.9682837                   -0.9464543
# 173 -0.9553187                   -0.9490720
# 174 -0.9688920                   -0.9509479
# 175 -0.9845276                   -0.9861609
# 176 -0.9740595                   -0.9802774
# 177 -0.9622491                   -0.9640982
# 178 -0.9679840                   -0.9831265
# 179 -0.9541937                   -0.9417140
# 180 -0.9423331                   -0.9162928
#     time.Body.acceleration.Z.std time.Gravity.acceleration.X.mean
# 1   -0.26002790                  0.9352232
# 2   -0.53062631                  0.9464685
# 3    0.05188410                  0.8029740
# 4   -0.51893263                  0.9515244
# 5   -0.15979979                  0.9259813
# 6   -0.26582449                  0.9281124
# 7   -0.13947794                  0.9352226
# 8   -0.16868873                  0.8625248
# 9   -0.21335197                  0.9360964
# 10   0.16422069                  0.9398097
# 11  -0.43713340                  0.9374831
# 12  -0.33348650                  0.9606478
# 13  -0.29731827                  0.9447593
# 14  -0.30092840                  0.9429303
# 15  -0.24282804                  0.9623744
# 16  -0.38741199                  0.9365067
# 17  -0.12047678                  0.9652176
# 18  -0.45702144                  0.9726250
# 19  -0.50432421                  0.9580675
# 20   0.15963128                  0.9325665
# 21  -0.14208853                  0.9135863
# 22  -0.39564507                  0.9630921
# 23  -0.41060606                  0.9668735
# 24  -0.22050354                  0.9108557
# 25  -0.42834806                  0.9238652
# 26  -0.42525752                  0.9130173
# 27  -0.22873422                  0.8999652
# 28  -0.28884002                  0.9597011
# 29  -0.58625281                  0.9639997
# 30  -0.05796365                  0.9518671
# ⋮   ⋮                            ⋮
# 151 -0.8260614                   -0.2488818
# 152 -0.9713112                   -0.1348320
# 153 -0.9003319                   -0.1454836
# 154 -0.9295868                   -0.1719931
# 155 -0.9654903                   -0.2067837
# 156 -0.9534767                   -0.1991331
# 157 -0.9846728                   -0.6800432
# 158 -0.9456538                   -0.1743492
# 159 -0.9429458                   -0.4184946
# 160 -0.9732235                   -0.3915650
# 161 -0.7172620                   -0.4611025
# 162 -0.9845000                   -0.6213097
# 163 -0.9866370                   -0.5304346
# 164 -0.9564503                   -0.4903345
# 165 -0.9872551                   -0.3467898
# 166 -0.9636910                   -0.2417585
# 167 -0.9670442                   -0.3447378
# 168 -0.9685625                   -0.4834706
# 169 -0.9252161                   -0.4767099
# 170 -0.9529784                   -0.5028143
# 171 -0.9324915                   -0.4059300
# 172 -0.9594715                   -0.4530697
# 173 -0.9483338                   -0.3785921
# 174 -0.9503930                   -0.1568522
# 175 -0.9876587                   -0.2206005
# 176 -0.9842333                   -0.5097542
# 177 -0.9725720                   -0.4724314
# 178 -0.9735670                   -0.3592925
# 179 -0.9626673                   -0.4206647
# 180 -0.9407073                   -0.5802528
#     time.Gravity.acceleration.Y.mean ⋯ frequency.Body.Gyro.Y.std
# 1   -0.28216502                      ⋯ -0.03350816
# 2   -0.21204587                      ⋯ -0.45366318
# 3   -0.27031482                      ⋯  0.08329506
# 4   -0.23391828                      ⋯ -0.36536121
# 5   -0.06682465                      ⋯ -0.61194088
# 6   -0.17992738                      ⋯ -0.43923879
# 7   -0.22333810                      ⋯ -0.13301029
# 8   -0.37098455                      ⋯ -0.41940088
# 9   -0.25964494                      ⋯ -0.48162441
# 10  -0.16176137                      ⋯  0.28658152
# 11  -0.12731587                      ⋯ -0.56720128
# 12  -0.13392219                      ⋯ -0.58793960
# 13  -0.18749703                      ⋯ -0.53094384
# 14  -0.22931615                      ⋯ -0.49747074
# 15  -0.12731808                      ⋯ -0.09413597
# 16  -0.26198636                      ⋯ -0.56888867
# 17  -0.15767382                      ⋯  0.09554560
# 18  -0.10044029                      ⋯ -0.50268338
# 19  -0.21469485                      ⋯ -0.33200871
# 20  -0.15909700                      ⋯ -0.29085938
# 21  -0.21710219                      ⋯ -0.19080572
# 22  -0.08382770                      ⋯ -0.20439282
# 23  -0.15598345                      ⋯ -0.44379833
# 24  -0.28365858                      ⋯ -0.31861851
# 25  -0.25431709                      ⋯ -0.46089066
# 26  -0.34660709                      ⋯ -0.53304695
# 27  -0.34444391                      ⋯  0.10770481
# 28  -0.11511624                      ⋯ -0.49589627
# 29  -0.08585403                      ⋯ -0.65465777
# 30  -0.03143417                      ⋯ -0.49099034
# ⋮   ⋮                                ⋱ ⋮
# 151  0.70554977                      ⋯ -0.9512320
# 152  0.94301794                      ⋯ -0.9826606
# 153  0.48539693                      ⋯ -0.9299554
# 154  0.89924255                      ⋯ -0.9599919
# 155 -0.01992702                      ⋯ -0.9681353
# 156  0.65879207                      ⋯ -0.9706278
# 157  0.72564662                      ⋯ -0.9598314
# 158  0.59999268                      ⋯ -0.9465999
# 159  0.63248408                      ⋯ -0.9607113
# 160  0.43843407                      ⋯ -0.9549973
# 161  0.62065892                      ⋯ -0.9322933
# 162  0.80301501                      ⋯ -0.9774918
# 163  0.56787949                      ⋯ -0.9830523
# 164  0.14407327                      ⋯ -0.9575530
# 165  0.80753537                      ⋯ -0.9922408
# 166  0.83703210                      ⋯ -0.9770325
# 167  0.73266125                      ⋯ -0.9651342
# 168  0.95489035                      ⋯ -0.9772578
# 169  0.95659381                      ⋯ -0.9453651
# 170  0.39344428                      ⋯ -0.9397279
# 171  0.58992243                      ⋯ -0.9503165
# 172 -0.13929768                      ⋯ -0.9534535
# 173  0.80337883                      ⋯ -0.9553437
# 174  0.65640094                      ⋯ -0.9599441
# 175  0.71975540                      ⋯ -0.9834578
# 176  0.75253664                      ⋯ -0.9819106
# 177  0.86488296                      ⋯ -0.9730925
# 178  0.73843070                      ⋯ -0.9577929
# 179  0.91516510                      ⋯ -0.9561825
# 180 -0.11915420                      ⋯ -0.9231319
#     frequency.Body.Gyro.Z.std frequency.Body.acceleration.Mag.mean
# 1   -0.4365622                -0.128623451
# 2   -0.4985546                -0.458514063
# 3   -0.1802329                -0.373516771
# 4   -0.5439976                -0.275156242
# 5   -0.4032198                -0.410463242
# 6   -0.4387687                -0.429380043
# 7   -0.2202712                 0.032227230
# 8   -0.3855054                -0.251266389
# 9   -0.2531739                -0.024158496
# 10  -0.2878209                -0.094260631
# 11  -0.6035442                -0.566060023
# 12  -0.4262321                -0.379836743
# 13  -0.2978475                -0.327229406
# 14  -0.3082434                -0.352156842
# 15  -0.4941175                -0.235683306
# 16  -0.5458964                -0.290031535
# 17  -0.2379415                -0.342363773
# 18  -0.4203671                -0.304992489
# 19  -0.5122092                -0.201386608
# 20  -0.4632700                -0.151243650
# 21  -0.1429742                -0.095217283
# 22  -0.2732929                -0.093023742
# 23  -0.4222565                -0.153116003
# 24  -0.4553339                -0.234600866
# 25  -0.5484098                -0.424386734
# 26  -0.5598566                -0.324289428
# 27  -0.2649572                -0.003533418
# 28  -0.4533379                -0.434618912
# 29  -0.7164585                -0.450804558
# 30  -0.3423672                -0.318801023
# ⋮   ⋮                         ⋮
# 151 -0.9165825                -0.8617676
# 152 -0.9631839                -0.9739940
# 153 -0.9577905                -0.8994637
# 154 -0.9600158                -0.9560010
# 155 -0.9857310                -0.9680205
# 156 -0.9783571                -0.9610463
# 157 -0.9754175                -0.9719574
# 158 -0.9832707                -0.9537691
# 159 -0.9369656                -0.9298190
# 160 -0.9853178                -0.9677471
# 161 -0.9154675                -0.7744819
# 162 -0.9717890                -0.9692691
# 163 -0.9800964                -0.9813890
# 164 -0.9663120                -0.9610356
# 165 -0.9768590                -0.9868006
# 166 -0.9672569                -0.9655243
# 167 -0.9721992                -0.9628408
# 168 -0.9633057                -0.9622350
# 169 -0.9471368                -0.9123517
# 170 -0.9588764                -0.9279769
# 171 -0.9706720                -0.9322796
# 172 -0.9752988                -0.9508481
# 173 -0.9564244                -0.9438674
# 174 -0.9697972                -0.9595355
# 175 -0.9864830                -0.9867884
# 176 -0.9631742                -0.9751102
# 177 -0.9749953                -0.9528271
# 178 -0.9836027                -0.9731711
# 179 -0.9658075                -0.9393897
# 180 -0.9656863                -0.9266043
#     frequency.Body.acceleration.Mag.std
# 1   -0.3980326
# 2   -0.5844560
# 3   -0.4574900
# 4   -0.4583448
# 5   -0.5921510
# 6   -0.5651625
# 7   -0.3247934
# 8   -0.4381498
# 9   -0.3813993
# 10  -0.4075775
# 11  -0.6329275
# 12  -0.5371840
# 13  -0.5503926
# 14  -0.5115737
# 15  -0.3932575
# 16  -0.4563731
# 17  -0.4698528
# 18  -0.5196369
# 19  -0.4216831
# 20  -0.3517068
# 21  -0.3608190
# 22  -0.3704719
# 23  -0.4088963
# 24  -0.4383890
# 25  -0.5655631
# 26  -0.5771052
# 27  -0.3899340
# 28  -0.5902658
# 29  -0.6511726
# 30  -0.5138920
# ⋮   ⋮
# 151 -0.7983009
# 152 -0.9760377
# 153 -0.8596060
# 154 -0.9455086
# 155 -0.9581119
# 156 -0.9490425
# 157 -0.9640568
# 158 -0.9444491
# 159 -0.9132673
# 160 -0.9584657
# 161 -0.6513532
# 162 -0.9665766
# 163 -0.9802963
# 164 -0.9575640
# 165 -0.9815998
# 166 -0.9683502
# 167 -0.9640518
# 168 -0.9625254
# 169 -0.9053740
# 170 -0.9105425
# 171 -0.9172580
# 172 -0.9443050
# 173 -0.9421333
# 174 -0.9494313
# 175 -0.9876485
# 176 -0.9751214
# 177 -0.9418941
# 178 -0.9710630
# 179 -0.9371880
# 180 -0.9219297
#     frequency.Body.acceleration.Jerk.Mag.mean
# 1   -0.05711940
# 2   -0.39511613
# 3   -0.43159145
# 4   -0.28975395
# 5   -0.37827849
# 6   -0.33593889
# 7    0.07301799
# 8   -0.14400989
# 9    0.06597273
# 10  -0.01807057
# 11  -0.56459134
# 12  -0.29335834
# 13  -0.25993401
# 14  -0.36081146
# 15  -0.10897821
# 16  -0.18676452
# 17  -0.34718013
# 18  -0.26948166
# 19  -0.05540142
# 20  -0.03841873
# 21  -0.12383441
# 22   0.02051895
# 23  -0.02991243
# 24  -0.15211150
# 25  -0.41403775
# 26  -0.16906435
# 27   0.05452695
# 28  -0.41864105
# 29  -0.31858781
# 30  -0.31687072
# ⋮   ⋮
# 151 -0.9333004
# 152 -0.9769408
# 153 -0.9679886
# 154 -0.9736812
# 155 -0.9875145
# 156 -0.9796873
# 157 -0.9806216
# 158 -0.9784441
# 159 -0.9626548
# 160 -0.9859057
# 161 -0.9600831
# 162 -0.9891382
# 163 -0.9880989
# 164 -0.9734362
# 165 -0.9939983
# 166 -0.9759496
# 167 -0.9699493
# 168 -0.9773564
# 169 -0.9486555
# 170 -0.9680663
# 171 -0.9617929
# 172 -0.9685611
# 173 -0.9624484
# 174 -0.9807544
# 175 -0.9885484
# 176 -0.9853741
# 177 -0.9796955
# 178 -0.9831081
# 179 -0.9622871
# 180 -0.9543206
#     frequency.Body.acceleration.Jerk.Mag.std frequency.Body.Gyro.Mag.mean
# 1   -0.10349240                              -0.19925257
# 2   -0.41744682                              -0.61022263
# 3   -0.45342601                              -0.31138645
# 4   -0.34241193                              -0.48916638
# 5   -0.44144775                              -0.66922854
# 6   -0.21123186                              -0.51861806
# 7   -0.02228696                              -0.09524605
# 8   -0.01867344                              -0.40951608
# 9    0.15828675                              -0.43837872
# 10  -0.04573723                               0.18507821
# 11  -0.51900425                              -0.56273325
# 12  -0.26894847                              -0.55192761
# 13  -0.27973202                              -0.51945170
# 14  -0.43627301                              -0.51460242
# 15  -0.16950650                              -0.41681785
# 16  -0.08985199                              -0.56975577
# 17  -0.36653742                              -0.35834436
# 18  -0.30568538                              -0.48426283
# 19  -0.09649997                              -0.32968112
# 20  -0.02213836                              -0.19290977
# 21  -0.27643613                              -0.30124185
# 22   0.05020876                              -0.41261691
# 23  -0.01395391                              -0.44250378
# 24  -0.11359192                              -0.26747237
# 25  -0.44445349                              -0.62033139
# 26  -0.16409197                              -0.53070481
# 27  -0.03106503                              -0.05200656
# 28  -0.40297998                              -0.53450916
# 29  -0.32045870                              -0.60928559
# 30  -0.32233754                              -0.51379748
# ⋮   ⋮                                        ⋮
# 151 -0.9218040                               -0.8621902
# 152 -0.9751265                               -0.9670934
# 153 -0.9636074                               -0.9301517
# 154 -0.9725301                               -0.9468126
# 155 -0.9872472                               -0.9702496
# 156 -0.9796572                               -0.9690144
# 157 -0.9794522                               -0.9656247
# 158 -0.9776049                               -0.9623490
# 159 -0.9556356                               -0.9460558
# 160 -0.9865402                               -0.9662393
# 161 -0.9636012                               -0.9101270
# 162 -0.9879015                               -0.9743052
# 163 -0.9881749                               -0.9798907
# 164 -0.9723361                               -0.9442184
# 165 -0.9943667                               -0.9840013
# 166 -0.9753054                               -0.9645867
# 167 -0.9680878                               -0.9620012
# 168 -0.9763819                               -0.9682571
# 169 -0.9515527                               -0.9301536
# 170 -0.9653592                               -0.9411307
# 171 -0.9637911                               -0.9445290
# 172 -0.9653776                               -0.9376926
# 173 -0.9616530                               -0.9454970
# 174 -0.9780443                               -0.9576816
# 175 -0.9897107                               -0.9843291
# 176 -0.9845685                               -0.9721130
# 177 -0.9795652                               -0.9698322
# 178 -0.9832851                               -0.9640014
# 179 -0.9580371                               -0.9615567
# 180 -0.9550947                               -0.9186053
#     frequency.Body.Gyro.Mag.std frequency.Body.Gyro.Jerk.Mag.mean
# 1   -0.32101795                 -0.3193086
# 2   -0.59974544                 -0.7519145
# 3   -0.26550455                 -0.5910369
# 4   -0.48175022                 -0.6450752
# 5   -0.72113700                 -0.7206823
# 6   -0.61532008                 -0.5827119
# 7   -0.14159840                 -0.2624428
# 8   -0.51224934                 -0.4995972
# 9   -0.46401913                 -0.5539461
# 10  -0.06147658                  0.1466186
# 11  -0.52926224                 -0.7703009
# 12  -0.60946622                 -0.6194610
# 13  -0.54688815                 -0.6232882
# 14  -0.51681157                 -0.5959651
# 15  -0.42915683                 -0.6285011
# 16  -0.63264329                 -0.6077516
# 17  -0.33154174                 -0.5476218
# 18  -0.58974151                 -0.5480536
# 19  -0.51064832                 -0.3665005
# 20  -0.34389491                 -0.1553399
# 21  -0.32745958                 -0.4730262
# 22  -0.49975980                 -0.5150653
# 23  -0.49480222                 -0.5611764
# 24  -0.37995184                 -0.3385271
# 25  -0.66890815                 -0.7105963
# 26  -0.65179284                 -0.5832493
# 27  -0.19621024                 -0.1803653
# 28  -0.66803280                 -0.5715944
# 29  -0.59393720                 -0.7243274
# 30  -0.56271453                 -0.6025816
# ⋮   ⋮                           ⋮
# 151 -0.8243194                  -0.9423669
# 152 -0.9548491                  -0.9859788
# 153 -0.9177601                  -0.9664553
# 154 -0.9236822                  -0.9757279
# 155 -0.9589751                  -0.9886953
# 156 -0.9600238                  -0.9827655
# 157 -0.9574960                  -0.9818905
# 158 -0.9497366                  -0.9829933
# 159 -0.9235524                  -0.9766390
# 160 -0.9590255                  -0.9818469
# 161 -0.8506613                  -0.9682516
# 162 -0.9661392                  -0.9904309
# 163 -0.9718062                  -0.9935638
# 164 -0.9316750                  -0.9718306
# 165 -0.9766790                  -0.9976174
# 166 -0.9554419                  -0.9842783
# 167 -0.9526444                  -0.9778213
# 168 -0.9592631                  -0.9846180
# 169 -0.9286949                  -0.9536960
# 170 -0.9188925                  -0.9741179
# 171 -0.9367870                  -0.9684039
# 172 -0.9337013                  -0.9609768
# 173 -0.9403738                  -0.9639496
# 174 -0.9461334                  -0.9781508
# 175 -0.9814688                  -0.9919010
# 176 -0.9610984                  -0.9902487
# 177 -0.9642059                  -0.9811198
# 178 -0.9613691                  -0.9785967
# 179 -0.9471003                  -0.9836091
# 180 -0.9034006                  -0.9558063
#     frequency.Body.Gyro.Jerk.Mag.std
# 1   -0.38160191
# 2   -0.77357406
# 3   -0.65567766
# 4   -0.65401015
# 5   -0.74572685
# 6   -0.52038548
# 7   -0.33614873
# 8   -0.42932347
# 9   -0.47640527
# 10   0.28783462
# 11  -0.75738578
# 12  -0.61293034
# 13  -0.63924238
# 14  -0.58907173
# 15  -0.61866772
# 16  -0.54908701
# 17  -0.57858004
# 18  -0.45566530
# 19  -0.40807891
# 20  -0.08416638
# 21  -0.58124019
# 22  -0.51767580
# 23  -0.56493401
# 24  -0.34928561
# 25  -0.76940839
# 26  -0.55810455
# 27  -0.17197577
# 28  -0.56744773
# 29  -0.75776808
# 30  -0.62435192
# ⋮   ⋮
# 151 -0.9326607
# 152 -0.9835695
# 153 -0.9636660
# 154 -0.9726457
# 155 -0.9880584
# 156 -0.9819834
# 157 -0.9793278
# 158 -0.9823051
# 159 -0.9727890
# 160 -0.9815851
# 161 -0.9704579
# 162 -0.9896280
# 163 -0.9935523
# 164 -0.9693198
# 165 -0.9975852
# 166 -0.9825682
# 167 -0.9754815
# 168 -0.9834345
# 169 -0.9555047
# 170 -0.9694030
# 171 -0.9717933
# 172 -0.9607729
# 173 -0.9619116
# 174 -0.9727986
# 175 -0.9927380
# 176 -0.9894927
# 177 -0.9819862
# 178 -0.9800970
# 179 -0.9825436
# 180 -0.9522905

# %%
# 1. Import relevant libraries
library(plyr)
library(dplyr)
library(reshape2)

# 2. Download and extract data
if (!file.exists("data/course_project_files.zip")) {
    download.file("https://d396qusza40orc.cloudfront.net/getdata%2Fprojectfiles%2FUCI%20HAR%20Dataset.zip", 
                 "data/course_project_files.zip")
}
unzip("data/course_project_files.zip", exdir="data")

# 2. Merge the training and test sets
# 3. / 2a. Extract only the mean and standard deviation for each measurement
# Now, the project description asks to extract only the mean and standard deviation *after* merging the dataset.
# However, the mean and standard deviation are a small subset of the overall data, so to minimise the machine
# workload, we'll read only them in, taking advantage of "read.fwf"'s column skipping functionality.

# Read in in the features list and find those with mean or standard columns
features <- readLines("data/UCI HAR Dataset/features.txt")
features <- sapply(features, function(x) { strsplit(x, " ")[[1]][[2]]})
meanandstd <- grepl(features, pattern = "(mean\\(\\)|std\\(\\))")

# If there is "mean"/"std", column width is +16 (i.e. read it in); otherwise -16 (i.e. skip it)
colwidths <- sapply(X = meanandstd, FUN = function(x) { ifelse(x, 16, -16)})
colnames <- features[meanandstd]

# Read in training data
x.training <- read.fwf("data/UCI HAR Dataset//train/X_train.txt", widths=colwidths, n = -1, col.names = colnames)
y.training <- readLines("data/UCI HAR Dataset/train/y_train.txt")
subject.training <- readLines("data/UCI HAR Dataset/train/subject_train.txt")

# Merge training data to form a single data.frame
training <- cbind(x.training, y.training, subject.training)

# Rename subject and activity to allow for merging with test data set
training <- training %>% rename(activity = y.training, subject = subject.training)

# Read in testing data
x.test <- read.fwf("data/UCI HAR Dataset/test/X_test.txt", widths=colwidths, n = -1, col.names = colnames)
y.test <- readLines("data/UCI HAR Dataset/test/y_test.txt")
subject.test <- readLines("data/UCI HAR Dataset/test/subject_test.txt")

# Merge testing data to form a single data.frame
test <- cbind(x.test, y.test, subject.test)

# Rename subject and activity to allow for merging with training data set
test <- test %>% rename(activity = y.test, subject = subject.test)

# Generate the total data set
total.data <- merge(training, test, all = TRUE)

# 4. Use descriptive activity names to name the activities in the data set
total.data$activity <- revalue(x = total.data$activity, 
                             c("1" = "walking", "2" = "walkingupstairs", "3" = "walkingdownstairs", 
                               "4" = "sitting", "5" = "standing", "6" = "laying"))

# 5. Appropriately label the data set with descriptive variable names
# The naming principles used are detailed in the code book and readme. 
# The comments below detail what each step is accomplishing.
col.names <- names(total.data)
new.col.names <- sub("BodyBody", "Body", col.names)  # Replace typo
new.col.names <- gsub("([A-Z])", "\\.\\1", new.col.names)  # Insert a period before capitals
new.col.names <- gsub("(mean)(.*)", "\\2.mean", new.col.names)  # Remove 'mean' and put it at end of line
new.col.names <- gsub("(std)(.*)", "\\2.std", new.col.names)  # Remove 'std' and put it at end of line
new.col.names <- gsub("(\\.+)", "\\.", new.col.names)  # Remove multiple periods and replace them with just one
new.col.names <- gsub("(^t)", "time", new.col.names)  # Replace "t" at start of line with "time"
new.col.names <- gsub("(^f)", "frequency", new.col.names)  # Replace "f" at start of line with "frequency"
new.col.names <- gsub("(Acc)", "acceleration", new.col.names)  # Replace "Acc" with "acceleration"
new.col.names <- tolower(new.col.names)  # Make all names lower case

# Apply revised names
names(total.data) <- new.col.names

# 6. Create a second, independent tidy data set with the average of each variable for each activity and each subject
melted.data <- melt(total.data, id=c("subject", "activity"))
tidy.data <- dcast(melted.data, activity + subject ~ variable, mean)
# Out:
# Error in rename(., activity = y.training, subject = subject.training): unused arguments (activity = y.training, subject = subject.training)
# Traceback:
#
# 1. training %>% rename(activity = y.training, subject = subject.training)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(expr, envir, enclos)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. rename(., activity = y.training, subject = subject.training)
